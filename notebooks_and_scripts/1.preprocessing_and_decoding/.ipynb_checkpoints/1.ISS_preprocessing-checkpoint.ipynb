# %% [markdown]
# # Notebook for processing ISS datasets

# %% [markdown]
# ## Priors

# %% [markdown]
# For in situ sequencing datasets, we use a Zeiss epifluorescence wide field equipment, see methods in Liu et al. After several rounds of imaging, needed for combinatorial decoding of the spots

# %% [markdown]
# ## import packages

# %%
import align_2d_tiles
import stitch_2d_mist
import tile_stitched_images
#import test_analysis

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
import glob
import tifffile
from xml.dom import minidom
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## find the samples/sections to decode

# %%
input_dir = 'D:/DIPG_ExportedTiles/'
sections = listdir(input_dir)
sections
# Out:
# ['10417-10043',
#  'A21-238_T_5',
#  'BT1873_pons_4',
#  'BT1873_ventricle_4',
#  'BT1954_5',
#  'Run4_AAA01043_10',
#  'UMPED103_pons_2',
#  'UMPED103_pons_2_thirdtimesthecharm',
#  'UMPED103_SVZ_6',
#  'UMPED65_A1_2',
#  'UMPED65_A2_2',
#  'UMPED83_pons',
#  'XT9824_4']

# %% [markdown]
# ### in this section we will specify which sections we **DO NOT** want to process

# %%
sections_to_remove = ['Cycle_1', 'Cycle_2', 'Cycle_3', 'Cycle_4', 'Cycle_5']

sections = listdir(input_dir)
sections = [x for x in sections if x not in sections_to_remove]

# %%
sections=['UMPED103_pons_2']

# %% [markdown]
# ### specify where you want to put the files

# %%
output_dir = 'F:/SAMPLES_DECODED\RUN2/'

# %% [markdown]
# # stack images

# %% [markdown]
# ## batch process

# %% [markdown]
# ## zeiss

# %% [markdown]
# we need to make sure that we are stacking the correct files

# %%
rounds
# Out:
# ['r1', 'r2', 'r3', 'r4', 'r5']

# %%
for i, section in enumerate(sections):
    input_dir_int = input_dir + section
    output_dir_int = output_dir + section + '/preprocessing/2DTiles/'
    if not os.path.exists(output_dir_int):
        os.makedirs(output_dir_int)
        
    onlyfiles = [f for f in listdir(input_dir_int) if isfile(join(input_dir_int, f))]
    onlytifs =  [k for k in onlyfiles if '.tif' in k]
    onlyfiles_df = pd.DataFrame(onlytifs)

    onlyfiles_split_tiles = onlyfiles_df[0].str.split('m',expand=True)
    onlyfiles_split_channel = onlyfiles_split_tiles[0].str.split('_',expand=True)

    tiles = list(np.unique(onlyfiles_split_tiles[1]))

    channels = list(np.unique(onlyfiles_split_channel[3]))
    rounds = list(np.unique(onlyfiles_split_channel[2]))
    rounds=['r1']
    for j, tile_number in enumerate(tiles):
        for i, round_number in enumerate(rounds):
            tile_filtered = [k for k in onlytifs if tile_number in k]
            round_filtered = [l for l in tile_filtered if round_number in l]
            round_filtered = (sorted(round_filtered))
            print(sorted(round_filtered))
# Out:
# ['DIPG_UPED103SVZ_r1_c1m001_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m001_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m001_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m001_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m001_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m002_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m002_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m002_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m002_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m002_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m003_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m003_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m003_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m003_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m003_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m004_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m004_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m004_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m004_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m004_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m005_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m005_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m005_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m005_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m005_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m006_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m006_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m006_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m006_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m006_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m007_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m007_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m007_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m007_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m007_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m008_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m008_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m008_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m008_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m008_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m009_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m009_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m009_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m009_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m009_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m010_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m010_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m010_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m010_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m010_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m011_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m011_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m011_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m011_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m011_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m012_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m012_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m012_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m012_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m012_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m013_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m013_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m013_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m013_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m013_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m014_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m014_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m014_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m014_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m014_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m015_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m015_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m015_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m015_ORG.tif', 'DIPG_UPED103SVZ_r1_c5
ORG.tif', 'DIPG_UPED103SVZ_r1_c5m176_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m177_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m177_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m177_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m177_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m177_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m178_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m178_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m178_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m178_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m178_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m179_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m179_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m179_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m179_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m179_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m180_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m180_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m180_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m180_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m180_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m181_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m181_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m181_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m181_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m181_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m182_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m182_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m182_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m182_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m182_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m183_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m183_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m183_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m183_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m183_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m184_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m184_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m184_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m184_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m184_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m185_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m185_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m185_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m185_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m185_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m186_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m186_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m186_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m186_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m186_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m187_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m187_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m187_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m187_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m187_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m188_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m188_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m188_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m188_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m188_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m189_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m189_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m189_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m189_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m189_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m190_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m190_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m190_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m190_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m190_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m191_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m191_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m191_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m191_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m191_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m192_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m192_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m192_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m192_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m192_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m193_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m193_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m193_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m193_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m193_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m194_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m194_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m194_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m194_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m194_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m195_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m195_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m195_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m195_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m195_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m196_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m196_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m196_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m196_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m196_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m197_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m197_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m197_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m197_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m197_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m198_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m198_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m198_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m198_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m198_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m199_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m199_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m199_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m199_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m199_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m200_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m200_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m200_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m200_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m200_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m201_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m201_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m201_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m201_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m201_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m202_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m202_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m202_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m202_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m202_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m203_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m203_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m203_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m203_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m203_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m204_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m204_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m204_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m204_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m204_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m205_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m205_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m205_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m205_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m205_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m206_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m206_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m206_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m206_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m206_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m207_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m207_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m207_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m207_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m207_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m208_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m208_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m208_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m208_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m208_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m209_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m209_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m209_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m209_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m209_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m210_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m210_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m210_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m210_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m210_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m211_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m211_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m211_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m211_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m211_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m212_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m212_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m212_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m212_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m212_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m213_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m213_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m213_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m213_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m213_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m214_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m214_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m214_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m214_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m214_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m215_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m215_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m215_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m215_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m215_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m216_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m216_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m216_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m216_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m216_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m217_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m217_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m217_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m217_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m217_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m218_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m218_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m218_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m218_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m218_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m219_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m219_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m219_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m219_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m219_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m220_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m220_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m220_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m220_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m220_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m221_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m221_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m221_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m221_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m221_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m222_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m222_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m222_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m222_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m222_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m223_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m223_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m223_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m223_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m223_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m224_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m224_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m224_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m224_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m224_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m225_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m225_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m225_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m225_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m225_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m226_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m226_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m226_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m226_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m226_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m227_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m227_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m227_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m227_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m227_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m228_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m228_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m228_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m228_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m228_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m229_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m229_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m229_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m229_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m229_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m230_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m230_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m230_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m230_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m230_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m231_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m231_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m231_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m231_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m231_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m232_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m232_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m232_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m232_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m232_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m233_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m233_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m233_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m233_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m233_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m234_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m234_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m234_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m234_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m234_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m235_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m235_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m235_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m235_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m235_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m236_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m236_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m236_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m236_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m236_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m237_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m237_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m237_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m237_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m237_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m238_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m238_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m238_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m238_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m238_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m239_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m239_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m239_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m239_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m239_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m240_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m240_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m240_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m240_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m240_ORG.tif']

# %%
for i, section in enumerate(sections):
    input_dir_int = input_dir + section
    output_dir_int = output_dir + section + '/preprocessing/2DTiles/'
    if not os.path.exists(output_dir_int):
        os.makedirs(output_dir_int)
        
    onlyfiles = [f for f in listdir(input_dir_int) if isfile(join(input_dir_int, f))]
    onlytifs =  [k for k in onlyfiles if '.tif' in k]
    onlyfiles_df = pd.DataFrame(onlytifs)

    onlyfiles_split_tiles = onlyfiles_df[0].str.split('m',expand=True)
    onlyfiles_split_channel = onlyfiles_split_tiles[0].str.split('_',expand=True)

    tiles = list(np.unique(onlyfiles_split_tiles[1]))

    channels = list(np.unique(onlyfiles_split_channel[3]))
    rounds = list(np.unique(onlyfiles_split_channel[2]))
    rounds=['r1']
    for j, tile_number in enumerate(tiles):
        for i, round_number in enumerate(rounds):
            tile_filtered = [k for k in onlytifs if tile_number in k]
            round_filtered = [l for l in tile_filtered if round_number in l]
            round_filtered = (sorted(round_filtered))
            print(sorted(round_filtered))
            for m, filtered_images in enumerate(round_filtered):
                with tifffile.TiffWriter(output_dir_int + 'Base_'+ str(i+1) + '_t' + str(j+1) + '.tif') as stack:
                    for filename in round_filtered:
                        stack.save(tifffile.imread(input_dir_int + '/' + filename))
# Out:
# ['DIPG_UPED103SVZ_r1_c1m001_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m001_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m001_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m001_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m001_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m002_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m002_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m002_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m002_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m002_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m003_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m003_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m003_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m003_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m003_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m004_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m004_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m004_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m004_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m004_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m005_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m005_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m005_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m005_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m005_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m006_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m006_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m006_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m006_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m006_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m007_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m007_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m007_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m007_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m007_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m008_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m008_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m008_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m008_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m008_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m009_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m009_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m009_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m009_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m009_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m010_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m010_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m010_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m010_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m010_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m011_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m011_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m011_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m011_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m011_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m012_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m012_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m012_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m012_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m012_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m013_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m013_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m013_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m013_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m013_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m014_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m014_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m014_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m014_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m014_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m015_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m015_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m015_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m015_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m015_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m016_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m016_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m016_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m016_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m016_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m017_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m017_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m017_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m017_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m017_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m018_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m018_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m018_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m018_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m018_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m019_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m019_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m019_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m019_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m019_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m020_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m020_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m020_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m020_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m020_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m021_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m021_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m021_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m021_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m021_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m022_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m022_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m022_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m022_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m022_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m023_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m023_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m023_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m023_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m023_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m024_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m024_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m024_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m024_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m024_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m025_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m025_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m025_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m025_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m025_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m026_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m026_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m026_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m026_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m026_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m027_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m027_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m027_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m027_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m027_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m028_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m028_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m028_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m028_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m028_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m029_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m029_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m029_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m029_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m029_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m030_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m030_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m030_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m030_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m030_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m031_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m031_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m031_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m031_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m031_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m032_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m032_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m032_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m032_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m032_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m033_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m033_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m033_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m033_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m033_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m034_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m034_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m034_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m034_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m034_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m035_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m035_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m035_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m035_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m035_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m036_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m036_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m036_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m036_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m036_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m037_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m037_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m037_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m037_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m037_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m038_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m038_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m038_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m038_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m038_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m039_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m039_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m039_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m039_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m039_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m040_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m040_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m040_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m040_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m040_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m041_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m041_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m041_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m041_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m041_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m042_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m042_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m042_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m042_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m042_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m043_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m043_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m043_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m043_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m043_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m044_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m044_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m044_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m044_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m044_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m045_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m045_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m045_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m045_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m045_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m046_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m046_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m046_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m046_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m046_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m047_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m047_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m047_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m047_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m047_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m048_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m048_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m048_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m048_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m048_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m049_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m049_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m049_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m049_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m049_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m050_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m050_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m050_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m050_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m050_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m051_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m051_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m051_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m051_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m051_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m052_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m052_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m052_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m052_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m052_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m053_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m053_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m053_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m053_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m053_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m054_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m054_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m054_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m054_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m054_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m055_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m055_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m055_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m055_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m055_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m056_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m056_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m056_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m056_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m056_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m057_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m057_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m057_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m057_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m057_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m058_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m058_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m058_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m058_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m058_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m059_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m059_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m059_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m059_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m059_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m060_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m060_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m060_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m060_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m060_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m061_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m061_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m061_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m061_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m061_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m062_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m062_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m062_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m062_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m062_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m063_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m063_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m063_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m063_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m063_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m064_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m064_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m064_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m064_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m064_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m065_ORG.tif', 'DIPG_UPED103SVZ_r1_c2
ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m226_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m226_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m226_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m226_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m226_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m227_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m227_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m227_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m227_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m227_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m228_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m228_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m228_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m228_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m228_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m229_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m229_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m229_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m229_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m229_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m230_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m230_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m230_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m230_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m230_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m231_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m231_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m231_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m231_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m231_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m232_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m232_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m232_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m232_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m232_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m233_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m233_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m233_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m233_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m233_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m234_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m234_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m234_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m234_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m234_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m235_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m235_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m235_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m235_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m235_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m236_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m236_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m236_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m236_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m236_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m237_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m237_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m237_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m237_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m237_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m238_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m238_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m238_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m238_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m238_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m239_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m239_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m239_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m239_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m239_ORG.tif']
# ['DIPG_UPED103SVZ_r1_c1m240_ORG.tif', 'DIPG_UPED103SVZ_r1_c2m240_ORG.tif', 'DIPG_UPED103SVZ_r1_c3m240_ORG.tif', 'DIPG_UPED103SVZ_r1_c4m240_ORG.tif', 'DIPG_UPED103SVZ_r1_c5m240_ORG.tif']

# %% [markdown]
# ## leica

# %%
for i, section in enumerate(sections):
    input_dir_int = input_dir + section
    output_dir_int = output_dir + section + '/preprocessing/2DTiles/'
    if not os.path.exists(output_dir_int):
        os.makedirs(output_dir_int)
        
    onlyfiles = [f for f in listdir(input_dir_int) if isfile(join(input_dir_int, f))]
    onlyfiles_df = pd.DataFrame(onlyfiles)
    onlyfiles_split = onlyfiles_df[0].str.split('_',expand=True)
    channels = list(np.unique(onlyfiles_split[7]))
    tiles = list(np.unique(onlyfiles_split[5]))
    rounds = list(np.unique(onlyfiles_split[3]))

    for j, tile_number in enumerate(tiles):
        for i, round_number in enumerate(rounds):
            tile_filtered = [k for k in onlytifs if tile_number in k]
            round_filtered = [l for l in tile_filtered if round_number in l]
            round_filtered = (sorted(round_filtered))
            print(sorted(round_filtered))
            for m, filtered_images in enumerate(round_filtered):
                with tifffile.TiffWriter(output_dir_int + 'Base_'+ str(i+1) + '_t' + str(j+1) + '.tif') as stack:
                    for filename in round_filtered:
                        stack.save(tifffile.imread(input_dir_int + '/' + filename))

# %% [markdown]
# # process metadata files

# %% [markdown]
# ## zeiss

# %%
for i, section in enumerate(sections):
    input_dir_int = input_dir + section + '/' 
    output_dir_int = output_dir + section + '/preprocessing/2DTiles/'
    path = input_dir_int
    metadatafiles = [n for n in listdir(path) if isfile(join(path, n))]
    onlyxml =  [k for k in metadatafiles if '.xml' in k]
    metadatafiles_cleaned = sorted([o for o in onlyxml if 'info.xml' in o])


    for p, meta in enumerate(metadatafiles_cleaned):
        metadata_txt = open(output_dir_int +"TileConfiguration_Base_" + str(p+1) + ".txt","a") 
        metadata_txt.write('# Define the number of dimensions we are working on\n')
        metadata_txt.write('dim = 2\n\n# Define the image coordinates\n')
        mydoc = minidom.parse(path + meta)
        tile =[]
        x =[]
        y =[]
        items = mydoc.getElementsByTagName('Bounds')
        for elem in items:

            tile.append(int(elem.attributes['StartM'].value))
            x.append(float(elem.attributes['StartX'].value))
            y.append(float(elem.attributes['StartY'].value))


        unique_tiles = list(np.unique(tile))
        x_reformatted = (x[:len(unique_tiles)])    
        y_reformatted = (y[:len(unique_tiles)])     
        dictionary = {'x': x_reformatted, 'y': y_reformatted}  

        df = pd.DataFrame(dictionary) 
        #df['x'] =((df.x-np.min(df.x))/.000000321) + 1
        #df['y'] =((df.y-np.min(df.y))/.000000321) + 1
        df.to_csv(output_dir_int + 'tile_coordinates_Base_'+str(p+1)+'.csv', index = False, header = None)    
        for elem in items:
            tile_value = elem.attributes['StartM'].value
            x_value = ((float(elem.attributes['StartX'].value)))
            y_value = ((float(elem.attributes['StartY'].value)))
            metadata_txt.write('Base_' + str(p+1) + '_t' + str(int(tile_value) + 1) +'; ; ' + '(' + str(x_value)+ ', ' + str(y_value) + ')' + '\n')

# %% [markdown]
# ## leica

# %%
for i, section in enumerate(sections):
    input_dir_int = input_dir + section + '/' 
    output_dir_int = output_dir + section + '/preprocessing/2DTiles/'
    path = input_dir_int
    metadatafiles = [n for n in listdir(path) if isfile(join(path, n))]
    onlyxml =  [k for k in metadatafiles if '.xml' in k]
    metadatafiles_cleaned = sorted([o for o in onlyxml if 'Properties.xml' in o])



    for p, meta in enumerate(metadatafiles_cleaned):
        metadata_txt = open(output_dir_int +"TileConfiguration_Base_" + str(p+1) + ".txt","a") 
        metadata_txt.write('# Define the number of dimensions we are working on\n')
        metadata_txt.write('dim = 2\n\n# Define the image coordinates\n')
        mydoc = minidom.parse(path + meta)
        tile =[]
        x =[]
        y =[]
        items = mydoc.getElementsByTagName('Tile')
        for elem in items:

            tile.append(int(elem.attributes['FieldX'].value))
            x.append(float(elem.attributes['PosX'].value))
            y.append(float(elem.attributes['PosY'].value))


        dict = {'x': x, 'y': y}     
        df = pd.DataFrame(dict) 
        df['x'] =((df.x-np.min(df.x))/.000000321) + 1
        df['y'] =((df.y-np.min(df.y))/.000000321) + 1

        for elem in items:
            tile_value = elem.attributes['FieldX'].value
            x_value = ((float(elem.attributes['PosX'].value))-np.min(x))/.000000321 + 1
            y_value = ((float(elem.attributes['PosY'].value))-np.min(y))/.000000321 + 1
        metadata_txt.write('Base_' + str(p+1) + '_t' + tile_value +'; ; ' + '(' + str(x_value)+ ', ' + str(y_value) + ')' + '\n')
    df.to_csv(output_dir_int + 'tile_coordinates_Base_'+str(p+1)+'.csv', index = False, header = None)

# %% [markdown]
# # matlab processing: alignment, stitching and tiling

# %% [markdown]
# ## add parameters

# %%
image_files = ('Base_1','Base_2','Base_3','Base_4','Base_5')

taglist = "C:/Users/chris.langseth/Downloads/Taglist_.csv"
nChannels = 5;
reference_round = 1;
tile_align_channel = 1; # for registration between rounds
tile_stitch_channel = 1; # Cy3   % for registration between tiles

# %% [markdown]
# ## align tiles

# %%
output_dir
# Out:
# 'F:/SAMPLES_DECODED\\RUN2/UMPED103_SVZ_6/r1/'

# %%
align = align_2d_tiles.initialize()

# %%
for i, section in enumerate(sections):
    print(section)
    output_directory = output_dir + section + '/preprocessing/'
    metadatafile = pd.read_csv(output_directory +  '2DTiles' + '/tile_coordinates_Base_1.csv', header = None);
    nTiles = len(metadatafile)
    align.align_2d_tiles((output_directory + '2DTiles'),image_files, output_directory, nChannels, nTiles, reference_round, tile_align_channel, nargout = 0)
# Out:
# UMPED103_SVZ_6

# %% [markdown]
# ## stitch using the mist algorithm

# %%
stitch = stitch_2d_mist.initialize()

# %%
for i, section in enumerate(sections):
    print(section)
    output_directory = output_dir + section + '/preprocessing/'
    stitch.stitch_2d_mist((output_directory + '2DTiles'),image_files, output_directory, nChannels, tile_stitch_channel, reference_round, nargout = 0)
# Out:
# UMPED103_SVZ_6

# %% [markdown]
# ## tile stitched images

# %%
tile = tile_stitched_images.initialize()

# %%
for i, section in enumerate(sections):
    #try:
    print(section)
    output_directory = output_dir + section + '/preprocessing/'
    tile.tile_stitched_images((output_directory + 'Stitched2DTiles'),image_files, output_directory, float(6000), 'windows', nargout = 0)
    #except MatlabRunTimeError:
    #    continue
# Out:
# UMPED103_pons_2

# %% [markdown]
# ## run preliminary analysis

# %%
decoding = [2,3,4,5]
from itertools import permutations  
perm = permutations(decoding) 
perm = list(perm)
perm
# Out:
# [(2, 3, 4, 5),
#  (2, 3, 5, 4),
#  (2, 4, 3, 5),
#  (2, 4, 5, 3),
#  (2, 5, 3, 4),
#  (2, 5, 4, 3),
#  (3, 2, 4, 5),
#  (3, 2, 5, 4),
#  (3, 4, 2, 5),
#  (3, 4, 5, 2),
#  (3, 5, 2, 4),
#  (3, 5, 4, 2),
#  (4, 2, 3, 5),
#  (4, 2, 5, 3),
#  (4, 3, 2, 5),
#  (4, 3, 5, 2),
#  (4, 5, 2, 3),
#  (4, 5, 3, 2),
#  (5, 2, 3, 4),
#  (5, 2, 4, 3),
#  (5, 3, 2, 4),
#  (5, 3, 4, 2),
#  (5, 4, 2, 3),
#  (5, 4, 3, 2)]

# %%
perm = [(3, 4, 2, 5)]

# %%
analysis = test_analysis.initialize()

# %%
for i, section in enumerate(sections):
    print(section)
    for j, decoding_int in enumerate(perm):
        decoding_mod = (float(perm[j][0]), float(perm[j][1]), float(perm[j][2]), float(perm[j][3]))
        print(decoding_mod)
        output_directory = output_dir + section + '/preprocessing/'
        newMetaDataFile = pd.read_csv(output_directory +  'ReslicedTiles' + '/tilepos.csv', header = None)
        nTiles = len(newMetaDataFile)
        analysis.test_analysis((output_directory + 'ReslicedTiles'),image_files, output_directory, nTiles, (decoding_mod), taglist, 'windows', nargout = 0)
# Out:
# 02A_Export
# (3.0, 4.0, 2.0, 5.0)

# %% [markdown]
# ## inspect data

# %%
barcodes_df = pd.read_csv("C:/Users/chris.langseth/Documents/mouseDev/" + section + "/preprocessing/3425spots_with_coords_noNNNNs.csv")

# %%
barcodes_df
# Out:
#          name barcode  pos1  pos2
# 0       Fezf1   GCCTA  1861   540
# 1        Lmo2   TTGTT  1892   465
# 2       Fezf2   TGTTT  1901   456
# 3       Efna2   CCGCG  1915   526
# 4       Fezf2   TGTTT  1922  1524
# ...       ...     ...   ...   ...
# 58700    Ntf3   GCACT  7555  8514
# 58701  Tfap2c   GCAAG  7572  8473
# 58702    Fgf8   GTCCA  7572  9199
# 58703    Fgf8   GTCCA  7576  8792
# 58704  Sema5a   GCTCA  7579  8724
#
# [58705 rows x 4 columns]

# %%
mpl.rcParams['figure.dpi'] = 500
grouped = barcodes_df.groupby('name')
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name1, group1 in grouped:
    ax.scatter(group1.pos1, group1.pos2, marker='.',linewidth = 0,s=0.05, label=name1)
#ax.legend()
plt.gca().invert_yaxis()
plt.axis('off')
plt.axis('scaled')
plt.show()
